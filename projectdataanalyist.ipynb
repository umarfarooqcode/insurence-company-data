# %% [markdown]
# Project Title = Insurance company data

# %% [markdown]
# Read download file

# %%
import pandas as pd
Project_file = pd.read_csv(r'C:\Users\user\Desktop\newproject\insurance.csv')

# %%
Project_file
# Out:
#      age     sex     bmi children smoker     region      charges
# 0     19  female  27.900        0    yes  southwest  16884.92400
# 1     18    male  33.770        1     no  southeast   1725.55230
# 2     28    male  33.000        3     no  southeast   4449.46200
# 3     33    male  22.705      NaN     no  northwest  21984.47061
# 4     32    male  28.880        0     no  northwest   3866.85520
# ..   ...     ...     ...      ...    ...        ...          ...
# 643   23  female  34.960        3     no  northwest   4466.62140
# 644   43    male  35.310        2     no  southeast  18806.14547
# 645   48     NaN  30.780        3     no  northeast  10141.13620
# 646   39    male  26.220        1     no  northwest   6123.56880
# 647   40  female  23.370        3    NaN  northeast   8252.28430
#
# [648 rows x 7 columns]

# %%
nan_value = Project_file.isna()
nan_value
# Out:
#        age    sex    bmi  children  smoker  region  charges
# 0    False  False  False     False   False   False    False
# 1    False  False  False     False   False   False    False
# 2    False  False  False     False   False   False    False
# 3    False  False  False      True   False   False    False
# 4    False  False  False     False   False   False    False
# ..     ...    ...    ...       ...     ...     ...      ...
# 643  False  False  False     False   False   False    False
# 644  False  False  False     False   False   False    False
# 645  False   True  False     False   False   False    False
# 646  False  False  False     False   False   False    False
# 647  False  False  False     False    True   False    False
#
# [648 rows x 7 columns]

# %%
nan_count = Project_file.isna().sum()
nan_count
# Out:
# age         0
# sex         2
# bmi         0
# children    2
# smoker      1
# region      1
# charges     2
# dtype: int64

# %%
data_clearing = Project_file.dropna()

# %%
data_clearing
# Out:
#      age     sex     bmi children smoker     region      charges
# 0     19  female  27.900        0    yes  southwest  16884.92400
# 1     18    male  33.770        1     no  southeast   1725.55230
# 2     28    male  33.000        3     no  southeast   4449.46200
# 4     32    male  28.880        0     no  northwest   3866.85520
# 6     46  female  33.440        1     no  southeast   8240.58960
# ..   ...     ...     ...      ...    ...        ...          ...
# 641   42    male  28.310        3    yes  northwest  32787.45859
# 642   61    male  33.915        0     no  northeast  13143.86485
# 643   23  female  34.960        3     no  northwest   4466.62140
# 644   43    male  35.310        2     no  southeast  18806.14547
# 646   39    male  26.220        1     no  northwest   6123.56880
#
# [640 rows x 7 columns]

# %% [markdown]
# Dropna function is use for the if you want to remove of cleaning the data

# %%
data_clearing
# Out:
#      age     sex     bmi children smoker     region      charges
# 0     19  female  27.900        0    yes  southwest  16884.92400
# 1     18    male  33.770        1     no  southeast   1725.55230
# 2     28    male  33.000        3     no  southeast   4449.46200
# 4     32    male  28.880        0     no  northwest   3866.85520
# 6     46  female  33.440        1     no  southeast   8240.58960
# ..   ...     ...     ...      ...    ...        ...          ...
# 641   42    male  28.310        3    yes  northwest  32787.45859
# 642   61    male  33.915        0     no  northeast  13143.86485
# 643   23  female  34.960        3     no  northwest   4466.62140
# 644   43    male  35.310        2     no  southeast  18806.14547
# 646   39    male  26.220        1     no  northwest   6123.56880
#
# [640 rows x 7 columns]

# %%
data_clearing.loc[:, 'children'] = pd.to_numeric(data_clearing['children'], errors='coerce')
mean_value = data_clearing[['charges','age','children']].mean()
df_filling = data_clearing.fillna(mean_value)
df_filling
# Out:
#      age     sex     bmi  children smoker     region      charges
# 0     19  female  27.900       0.0    yes  southwest  16884.92400
# 1     18    male  33.770       1.0     no  southeast   1725.55230
# 2     28    male  33.000       3.0     no  southeast   4449.46200
# 4     32    male  28.880       0.0     no  northwest   3866.85520
# 6     46  female  33.440       1.0     no  southeast   8240.58960
# ..   ...     ...     ...       ...    ...        ...          ...
# 641   42    male  28.310       3.0    yes  northwest  32787.45859
# 642   61    male  33.915       0.0     no  northeast  13143.86485
# 643   23  female  34.960       3.0     no  northwest   4466.62140
# 644   43    male  35.310       2.0     no  southeast  18806.14547
# 646   39    male  26.220       1.0     no  northwest   6123.56880
#
# [640 rows x 7 columns]

# %%
df_file = pd.read_csv(r'C:\Users\user\Desktop\newproject\BusinessRules.csv')

# %%
df_file
# Out:
#        BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0              2014        AL     82285       HIOS           7
# 1              2014        AL     82285       HIOS           7
# 2              2014        AL     82285       HIOS           7
# 3              2014        AL     82285       HIOS           7
# 4              2014        AL     82285       HIOS           7
# ...             ...       ...       ...        ...         ...
# 21080          2016        WV     94562      SERFF           2
# 21081          2016        WV     96480      SERFF           2
# 21082          2016        WV     96480      SERFF           2
# 21083          2016        WV     96480      SERFF           2
# 21084          2016        WV     96480      SERFF           2
#
#                 ImportDate  IssuerId2         TIN   ProductId  \
# 0      2014-01-21 08:29:49      82285  94-2761537         NaN
# 1      2014-01-21 08:29:49      82285  94-2761537         NaN
# ...

# %%
check_nan_value = df_file.isna()

# %%
check_nan_value
# Out:
#        BusinessYear  StateCode  IssuerId  SourceName  VersionNum  ImportDate  \
# 0             False      False     False       False       False       False
# 1             False      False     False       False       False       False
# 2             False      False     False       False       False       False
# 3             False      False     False       False       False       False
# 4             False      False     False       False       False       False
# ...             ...        ...       ...         ...         ...         ...
# 21080         False      False     False       False       False       False
# 21081         False      False     False       False       False       False
# 21082         False      False     False       False       False       False
# 21083         False      False     False       False       False       False
# 21084         False      False     False       False       False       False
#
# ...

# %%
which_value_nan = df_file.isna().sum()
which_value_nan
# Out:
# BusinessYear                                0
# StateCode                                   0
# IssuerId                                    0
# SourceName                                  0
# VersionNum                                  0
# ImportDate                                  0
# IssuerId2                                   0
# TIN                                         0
# ProductId                                1683
# StandardComponentId                      1012
# EnrolleeContractRateDeterminationRule     247
# TwoParentFamilyMaxDependentsRule          539
# SingleParentFamilyMaxDependentsRule       539
# DependentMaximumAgRule                    183
# ChildrenOnlyContractMaxChildrenRule       669
# DomesticPartnerAsSpouseIndicator          510
# SameSexPartnerAsSpouseIndicator           510
# AgeDeterminationRule                      411
# MinimumTobaccoFreeMonthsRule              404
# CohabitationRule                          355
# ...

# %%
filling_data_mean = df_file['ProductId'].mean()
filling_mean = df_file.fillna(filling_data_mean)
filling_mean = df_file.fillna(0)
df_file['ProductId'] = pd.to_numeric(df_file['ProductId'], errors='coerce')

# Calculate the mean
filling_data_mean = df_file['ProductId'].mean()

# Replace NaN values with the mean
filling_mean = df_file.fillna(filling_data_mean)

# %%
data_clearing
# Out:
#      age     sex     bmi  children smoker     region      charges
# 0     19  female  27.900       0.0    yes  southwest  16884.92400
# 1     18    male  33.770       1.0     no  southeast   1725.55230
# 2     28    male  33.000       3.0     no  southeast   4449.46200
# 4     32    male  28.880       0.0     no  northwest   3866.85520
# 6     46  female  33.440       1.0     no  southeast   8240.58960
# ..   ...     ...     ...       ...    ...        ...          ...
# 641   42    male  28.310       3.0    yes  northwest  32787.45859
# 642   61    male  33.915       0.0     no  northeast  13143.86485
# 643   23  female  34.960       3.0     no  northwest   4466.62140
# 644   43    male  35.310       2.0     no  southeast  18806.14547
# 646   39    male  26.220       1.0     no  northwest   6123.56880
#
# [640 rows x 7 columns]

# %%
min_value = data_clearing['children'].min()
min_value
# Out:
# 0.0

# %%
max_value = data_clearing['children'].max()
max_value
# Out:
# 5.0

# %%
min_value = df_file['IssuerId'].min()
min_value
# Out:
# 10046

# %%
max_value = df_file['IssuerId'].max()
max_value
# Out:
# 99969

# %%
df_file
# Out:
#        BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0              2014        AL     82285       HIOS           7
# 1              2014        AL     82285       HIOS           7
# 2              2014        AL     82285       HIOS           7
# 3              2014        AL     82285       HIOS           7
# 4              2014        AL     82285       HIOS           7
# ...             ...       ...       ...        ...         ...
# 21080          2016        WV     94562      SERFF           2
# 21081          2016        WV     96480      SERFF           2
# 21082          2016        WV     96480      SERFF           2
# 21083          2016        WV     96480      SERFF           2
# 21084          2016        WV     96480      SERFF           2
#
#                 ImportDate  IssuerId2         TIN  ProductId  \
# 0      2014-01-21 08:29:49      82285  94-2761537        NaN
# 1      2014-01-21 08:29:49      82285  94-2761537        NaN
# ...

# %%
summary_stats = df_file[['BusinessYear','StateCode','IssuerId']].describe()
summary_stats
# Out:
#        BusinessYear      IssuerId
# count  21085.000000  21085.000000
# mean    2015.321745  52857.554517
# std        0.646315  26097.535028
# min     2014.000000  10046.000000
# 25%     2015.000000  31609.000000
# 50%     2015.000000  49046.000000
# 75%     2016.000000  76526.000000
# max     2016.000000  99969.000000

# %%
missing_values = df_file.isnull().sum()

# Check for missing values in a specific column
missing_values_column = df_file[['BusinessYear',	'StateCode',	'IssuerId',	'SourceName',	'VersionNum',	'ImportDate',	'IssuerId2',	'TIN','ProductId',	'StandardComponentId',	'DependentMaximumAgRule'	,'ChildrenOnlyContractMaxChildrenRule',	'DomesticPartnerAsSpouseIndicator',	'SameSexPartnerAsSpouseIndicator',	'AgeDeterminationRule',	'MinimumTobaccoFreeMonthsRule',	'CohabitationRule',	'RowNumber',	'MarketCoverage',	'DentalOnlyPlan'
]].isnull().sum()
missing_values_column
# Out:
# BusinessYear                               0
# StateCode                                  0
# IssuerId                                   0
# SourceName                                 0
# VersionNum                                 0
# ImportDate                                 0
# IssuerId2                                  0
# TIN                                        0
# ProductId                              21085
# StandardComponentId                     1012
# DependentMaximumAgRule                   183
# ChildrenOnlyContractMaxChildrenRule      669
# DomesticPartnerAsSpouseIndicator         510
# SameSexPartnerAsSpouseIndicator          510
# AgeDeterminationRule                     411
# MinimumTobaccoFreeMonthsRule             404
# CohabitationRule                         355
# RowNumber                                  0
# MarketCoverage                          1208
# DentalOnlyPlan                          1208
# dtype: int64

# %%
numeric_columns = df_file.select_dtypes(include=['number'])
median_values = numeric_columns.median()
df_file.fillna(median_values, inplace=True)

# %%
missing_values = df_file.isnull().sum()

# Check for missing values in a specific column
missing_values_column = df_file[['BusinessYear',	'StateCode',	'IssuerId',	'SourceName',	'VersionNum',	'ImportDate',	'IssuerId2',	'TIN','ProductId',	'StandardComponentId',	'DependentMaximumAgRule'	,'ChildrenOnlyContractMaxChildrenRule',	'DomesticPartnerAsSpouseIndicator',	'SameSexPartnerAsSpouseIndicator',	'AgeDeterminationRule',	'MinimumTobaccoFreeMonthsRule',	'CohabitationRule',	'RowNumber',	'MarketCoverage',	'DentalOnlyPlan'
]].isnull().sum()
missing_values_column
# Out:
# BusinessYear                               0
# StateCode                                  0
# IssuerId                                   0
# SourceName                                 0
# VersionNum                                 0
# ImportDate                                 0
# IssuerId2                                  0
# TIN                                        0
# ProductId                              21085
# StandardComponentId                     1012
# DependentMaximumAgRule                   183
# ChildrenOnlyContractMaxChildrenRule      669
# DomesticPartnerAsSpouseIndicator         510
# SameSexPartnerAsSpouseIndicator          510
# AgeDeterminationRule                     411
# MinimumTobaccoFreeMonthsRule             404
# CohabitationRule                         355
# RowNumber                                  0
# MarketCoverage                          1208
# DentalOnlyPlan                          1208
# dtype: int64

# %%
null_check_value = df_file.isna()
null_check_value
# Out:
#        BusinessYear  StateCode  IssuerId  SourceName  VersionNum  ImportDate  \
# 0             False      False     False       False       False       False
# 1             False      False     False       False       False       False
# 2             False      False     False       False       False       False
# 3             False      False     False       False       False       False
# 4             False      False     False       False       False       False
# ...             ...        ...       ...         ...         ...         ...
# 21080         False      False     False       False       False       False
# 21081         False      False     False       False       False       False
# 21082         False      False     False       False       False       False
# 21083         False      False     False       False       False       False
# 21084         False      False     False       False       False       False
#
# ...

# %%
df_file
# Out:
#        BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0              2014        AL     82285       HIOS           7
# 1              2014        AL     82285       HIOS           7
# 2              2014        AL     82285       HIOS           7
# 3              2014        AL     82285       HIOS           7
# 4              2014        AL     82285       HIOS           7
# ...             ...       ...       ...        ...         ...
# 21080          2016        WV     94562      SERFF           2
# 21081          2016        WV     96480      SERFF           2
# 21082          2016        WV     96480      SERFF           2
# 21083          2016        WV     96480      SERFF           2
# 21084          2016        WV     96480      SERFF           2
#
#                 ImportDate  IssuerId2         TIN  ProductId  \
# 0      2014-01-21 08:29:49      82285  94-2761537        NaN
# 1      2014-01-21 08:29:49      82285  94-2761537        NaN
# ...

# %%
# Convert non-numeric values to NaN
numeric_columns = df_file.select_dtypes(include=['number'])
numeric_columns = numeric_columns.apply(pd.to_numeric, errors='coerce')

# Calculate the median for numeric columns
median_values = numeric_columns.median()

# Fill NaN values in the DataFrame with median values
df_file.fillna(median_values, inplace=True)

# %%
df_file
# Out:
#        BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0              2014        AL     82285       HIOS           7
# 1              2014        AL     82285       HIOS           7
# 2              2014        AL     82285       HIOS           7
# 3              2014        AL     82285       HIOS           7
# 4              2014        AL     82285       HIOS           7
# ...             ...       ...       ...        ...         ...
# 21080          2016        WV     94562      SERFF           2
# 21081          2016        WV     96480      SERFF           2
# 21082          2016        WV     96480      SERFF           2
# 21083          2016        WV     96480      SERFF           2
# 21084          2016        WV     96480      SERFF           2
#
#                 ImportDate  IssuerId2         TIN  ProductId  \
# 0      2014-01-21 08:29:49      82285  94-2761537        NaN
# 1      2014-01-21 08:29:49      82285  94-2761537        NaN
# ...

# %%
sum_issured_id = df_file['IssuerId'].sum()
sum_issured_id
# Out:
# 1114501537

# %%
mean_versionnum = df_file['VersionNum'].mean()
mean_versionnum
# Out:
# 6.791036281716861

# %%
medium_issuerid2 = df_file['IssuerId2'].median()
median_values
# Out:
# BusinessYear     2015.0
# IssuerId        49046.0
# VersionNum          6.0
# IssuerId2       49046.0
# ProductId           NaN
# RowNumber          10.0
# dtype: float64

# %%
sum_RowNumber = df_file['RowNumber'].mean()
sum_RowNumber
# Out:
# 11.050035570310648

# %%
clean_values_data = df_file.dropna(axis=0)
clean_values_data
# Out:
# Empty DataFrame
# Columns: [BusinessYear, StateCode, IssuerId, SourceName, VersionNum, ImportDate, IssuerId2, TIN, ProductId, StandardComponentId, EnrolleeContractRateDeterminationRule, TwoParentFamilyMaxDependentsRule, SingleParentFamilyMaxDependentsRule, DependentMaximumAgRule, ChildrenOnlyContractMaxChildrenRule, DomesticPartnerAsSpouseIndicator, SameSexPartnerAsSpouseIndicator, AgeDeterminationRule, MinimumTobaccoFreeMonthsRule, CohabitationRule, RowNumber, MarketCoverage, DentalOnlyPlan]
# Index: []
#
# [0 rows x 23 columns]

# %%
df_file
# Out:
#        BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0              2014        AL     82285       HIOS           7
# 1              2014        AL     82285       HIOS           7
# 2              2014        AL     82285       HIOS           7
# 3              2014        AL     82285       HIOS           7
# 4              2014        AL     82285       HIOS           7
# ...             ...       ...       ...        ...         ...
# 21080          2016        WV     94562      SERFF           2
# 21081          2016        WV     96480      SERFF           2
# 21082          2016        WV     96480      SERFF           2
# 21083          2016        WV     96480      SERFF           2
# 21084          2016        WV     96480      SERFF           2
#
#                 ImportDate  IssuerId2         TIN  ProductId  \
# 0      2014-01-21 08:29:49      82285  94-2761537        NaN
# 1      2014-01-21 08:29:49      82285  94-2761537        NaN
# ...

# %%
any_missing_values = df_file.isna().any()
any_missing_values
# Out:
# BusinessYear                             False
# StateCode                                False
# IssuerId                                 False
# SourceName                               False
# VersionNum                               False
# ImportDate                               False
# IssuerId2                                False
# TIN                                      False
# ProductId                                 True
# StandardComponentId                       True
# EnrolleeContractRateDeterminationRule     True
# TwoParentFamilyMaxDependentsRule          True
# SingleParentFamilyMaxDependentsRule       True
# DependentMaximumAgRule                    True
# ChildrenOnlyContractMaxChildrenRule       True
# DomesticPartnerAsSpouseIndicator          True
# SameSexPartnerAsSpouseIndicator           True
# AgeDeterminationRule                      True
# MinimumTobaccoFreeMonthsRule              True
# CohabitationRule                          True
# ...

# %%
any_count_values = df_file.isna().sum()
any_count_values
# Out:
# BusinessYear                                 0
# StateCode                                    0
# IssuerId                                     0
# SourceName                                   0
# VersionNum                                   0
# ImportDate                                   0
# IssuerId2                                    0
# TIN                                          0
# ProductId                                21085
# StandardComponentId                       1012
# EnrolleeContractRateDeterminationRule      247
# TwoParentFamilyMaxDependentsRule           539
# SingleParentFamilyMaxDependentsRule        539
# DependentMaximumAgRule                     183
# ChildrenOnlyContractMaxChildrenRule        669
# DomesticPartnerAsSpouseIndicator           510
# SameSexPartnerAsSpouseIndicator            510
# AgeDeterminationRule                       411
# MinimumTobaccoFreeMonthsRule               404
# CohabitationRule                           355
# ...

# %%
# Forward fill missing values
df_file.ffill(inplace=True)

# Backward fill missing values
df_file.bfill(inplace=True)

# %%
any_count_values = df_file.isna().sum()
any_count_values
# Out:
# BusinessYear                                 0
# StateCode                                    0
# IssuerId                                     0
# SourceName                                   0
# VersionNum                                   0
# ImportDate                                   0
# IssuerId2                                    0
# TIN                                          0
# ProductId                                21085
# StandardComponentId                          0
# EnrolleeContractRateDeterminationRule        0
# TwoParentFamilyMaxDependentsRule             0
# SingleParentFamilyMaxDependentsRule          0
# DependentMaximumAgRule                       0
# ChildrenOnlyContractMaxChildrenRule          0
# DomesticPartnerAsSpouseIndicator             0
# SameSexPartnerAsSpouseIndicator              0
# AgeDeterminationRule                         0
# MinimumTobaccoFreeMonthsRule                 0
# CohabitationRule                             0
# ...

# %%
import numpy as np
random_values = np.random.randn(*df_file.shape)
random_values
# Out:
# array([[ 0.93311119, -1.60157593, -0.05742861, ..., -0.67582663,
#         -1.32520489,  0.5990142 ],
#        [-0.67873328,  0.34818768, -0.94304356, ..., -0.27035432,
#         -0.0045081 , -1.22318224],
#        [ 0.89610669,  0.88658821,  1.35277425, ...,  0.19681021,
#         -0.22425024,  0.25798385],
#        ...,
#        [ 0.79110075, -0.51984593, -0.29572399, ...,  1.7307018 ,
#          0.97316806,  0.77055336],
#        [ 0.93991368,  0.55166207, -0.58973995, ..., -0.4467656 ,
#         -0.04165831, -0.35206588],
#        [-0.99969016, -0.67406266,  1.46087556, ...,  1.16979663,
#         -1.40063838,  1.72257525]])

# %%
import pandas as pd

# Create a sample DataFrame with missing values
data = {'A': [1, 2, None, 4, None],
        'B': [None, 5, 6, None, None]}
df = pd.DataFrame(data)

# Forward fill the missing values
df_ffill = df.fillna(method='ffill')
print("DataFrame after forward fill:")
print(df_ffill)

# Backward fill the missing values
df_bfill = df.fillna(method='bfill')
print("\nDataFrame after backward fill:")
print(df_bfill)
# Out:
# DataFrame after forward fill:
#      A    B
# 0  1.0  NaN
# 1  2.0  5.0
# 2  2.0  6.0
# 3  4.0  6.0
# 4  4.0  6.0
#
# DataFrame after backward fill:
#      A    B
# 0  1.0  5.0
# 1  2.0  5.0
# 2  4.0  6.0
# 3  4.0  NaN
# 4  NaN  NaN
# C:\Users\user\AppData\Local\Temp\ipykernel_35000\2169802541.py:9: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_ffill = df.fillna(method='ffill')
# C:\Users\user\AppData\Local\Temp\ipykernel_35000\2169802541.py:14: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_bfill = df.fillna(method='bfill')

# %%
df_file
# Out:
#        BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0              2014        AL     82285       HIOS           7
# 1              2014        AL     82285       HIOS           7
# 2              2014        AL     82285       HIOS           7
# 3              2014        AL     82285       HIOS           7
# 4              2014        AL     82285       HIOS           7
# ...             ...       ...       ...        ...         ...
# 21080          2016        WV     94562      SERFF           2
# 21081          2016        WV     96480      SERFF           2
# 21082          2016        WV     96480      SERFF           2
# 21083          2016        WV     96480      SERFF           2
# 21084          2016        WV     96480      SERFF           2
#
#                 ImportDate  IssuerId2         TIN  ProductId  \
# 0      2014-01-21 08:29:49      82285  94-2761537        NaN
# 1      2014-01-21 08:29:49      82285  94-2761537        NaN
# ...

# %%
df_file['ImportDate'].head(10)
# Out:
# 0   2014-01-21 08:29:49
# 1   2014-01-21 08:29:49
# 2   2014-01-21 08:29:49
# 3   2014-01-21 08:29:49
# 4   2014-01-21 08:29:49
# 5   2013-10-15 07:27:56
# 6   2013-10-15 07:27:56
# 7   2013-06-06 10:50:48
# 8   2014-01-16 07:24:04
# 9   2014-03-19 07:06:49
# Name: ImportDate, dtype: datetime64[ns]

# %%
df_file['ImportDate'] = pd.to_datetime(df_file['ImportDate']) 
print(df_file)
# Out:
#        BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0              2014        AL     82285       HIOS           7
# 1              2014        AL     82285       HIOS           7
# 2              2014        AL     82285       HIOS           7
# 3              2014        AL     82285       HIOS           7
# 4              2014        AL     82285       HIOS           7
# ...             ...       ...       ...        ...         ...
# 21080          2016        WV     94562      SERFF           2
# 21081          2016        WV     96480      SERFF           2
# 21082          2016        WV     96480      SERFF           2
# 21083          2016        WV     96480      SERFF           2
# 21084          2016        WV     96480      SERFF           2
#
#                ImportDate  IssuerId2         TIN  ProductId  \
# 0     2014-01-21 08:29:49      82285  94-2761537        NaN
# 1     2014-01-21 08:29:49      82285  94-2761537        NaN
# ...

# %%
df_file
# Out:
#        BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0              2014        AL     82285       HIOS           7
# 1              2014        AL     82285       HIOS           7
# 2              2014        AL     82285       HIOS           7
# 3              2014        AL     82285       HIOS           7
# 4              2014        AL     82285       HIOS           7
# ...             ...       ...       ...        ...         ...
# 21080          2016        WV     94562      SERFF           2
# 21081          2016        WV     96480      SERFF           2
# 21082          2016        WV     96480      SERFF           2
# 21083          2016        WV     96480      SERFF           2
# 21084          2016        WV     96480      SERFF           2
#
#                ImportDate  IssuerId2         TIN  ProductId  \
# 0     2014-01-21 08:29:49      82285  94-2761537        NaN
# 1     2014-01-21 08:29:49      82285  94-2761537        NaN
# ...

# %%
pd.to_datetime('2022-01-01')

df_file['ImportDate'] = pd.to_datetime(df_file['ImportDate'])
df_file['ImportDate'].dt.year
df_file['ImportDate'].dt.month
df_file['ImportDate'].dt.day
# Out:
# 0        21
# 1        21
# 2        21
# 3        21
# 4        21
#          ..
# 21080    20
# 21081    20
# 21082    20
# 21083    20
# 21084    20
# Name: ImportDate, Length: 21085, dtype: int32

# %%
pd.date_range(start='2022-01-01', end='2022-01-31', freq='D')
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07', '2022-01-08',
#                '2022-01-09', '2022-01-10', '2022-01-11', '2022-01-12',
#                '2022-01-13', '2022-01-14', '2022-01-15', '2022-01-16',
#                '2022-01-17', '2022-01-18', '2022-01-19', '2022-01-20',
#                '2022-01-21', '2022-01-22', '2022-01-23', '2022-01-24',
#                '2022-01-25', '2022-01-26', '2022-01-27', '2022-01-28',
#                '2022-01-29', '2022-01-30', '2022-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.Period('2022-01')
# Out:
# Period('2022-01', 'M')

# %%
df_file['year'] = df_file['ImportDate'].dt.year
df_file['month'] = df_file['ImportDate'].dt.month
df_file['weekday'] = df_file['ImportDate'].dt.weekday
df_file['day'] = df_file['ImportDate'].dt.day
df_file['']

# %%
df_file_december = df_file[df_file.month==12].head(10)
df_file_december
# Out:
#       BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 1051          2014        PA     75729       HIOS          11
# 2381          2015        AL     68259       HIOS           8
# 2382          2015        AL     68259       HIOS           8
# 2383          2015        AL     68259       HIOS           8
# 2384          2015        AL     68259       HIOS           8
# 2385          2015        AL     68259       HIOS           8
# 2386          2015        AL     68259       HIOS           8
# 2387          2015        AL     68259       HIOS           8
# 2388          2015        AL     68259       HIOS           8
# 2389          2015        AL     68259       HIOS           8
#
#               ImportDate  IssuerId2         TIN  ProductId  \
# 1051 2013-12-20 07:30:10      75729  20-4275139        NaN
# 2381 2014-12-11 04:09:12      68259  63-0899562        NaN
# 2382 2014-12-11 04:09:12      68259  63-0899562        NaN
# ...

# %%
df_file_matric = df_file_december[['IssuerId','IssuerId2','month']]
file_df_total = df_file_matric.sum()
file_df_total
# Out:
# IssuerId     690060
# IssuerId2    690060
# month           120
# dtype: int64

# %%
df_file
# Out:
#        BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0              2014        AL     82285       HIOS           7
# 1              2014        AL     82285       HIOS           7
# 2              2014        AL     82285       HIOS           7
# 3              2014        AL     82285       HIOS           7
# 4              2014        AL     82285       HIOS           7
# ...             ...       ...       ...        ...         ...
# 21080          2016        WV     94562      SERFF           2
# 21081          2016        WV     96480      SERFF           2
# 21082          2016        WV     96480      SERFF           2
# 21083          2016        WV     96480      SERFF           2
# 21084          2016        WV     96480      SERFF           2
#
#                ImportDate  IssuerId2         TIN  ProductId  \
# 0     2014-01-21 08:29:49      82285  94-2761537        NaN
# 1     2014-01-21 08:29:49      82285  94-2761537        NaN
# ...

# %%
df_file['']

# %%
# Out:
#        BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0              2014        AL     82285       HIOS           7
# 1              2014        AL     82285       HIOS           7
# 2              2014        AL     82285       HIOS           7
# 3              2014        AL     82285       HIOS           7
# 4              2014        AL     82285       HIOS           7
# ...             ...       ...       ...        ...         ...
# 21080          2016        WV     94562      SERFF           2
# 21081          2016        WV     96480      SERFF           2
# 21082          2016        WV     96480      SERFF           2
# 21083          2016        WV     96480      SERFF           2
# 21084          2016        WV     96480      SERFF           2
#
#                 ImportDate  IssuerId2         TIN   ProductId  \
# 0      2014-01-21 08:29:49      82285  94-2761537         NaN
# 1      2014-01-21 08:29:49      82285  94-2761537         NaN
# ...

# %%
df_file['charges'] = pd.concat(df_file['SourceName'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 df_file['charges'] = pd.concat(df_file['SourceName'])
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\concat.py:382, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379 elif copy and using_copy_on_write():
#     380     copy = False
# --> 382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#     385     ignore_index=ignore_index,
#     386     join=join,
#     387     keys=keys,
#     388     levels=levels,
#     389     names=names,
#     390     verify_integrity=verify_integrity,
#     391     copy=copy,
#     392     sort=sort,
#     393 )
#     395 return op.get_result()
#
# ...

# %%
df_file.sort_values('IssuerId', ascending=False).head(10)
# Out:
#        BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 11444          2015        OH     99969      SERFF           6
# 11439          2015        OH     99969      SERFF           6
# 20373          2016        OH     99969      SERFF          10
# 20374          2016        OH     99969      SERFF          10
# 11449          2015        OH     99969      SERFF           6
# 11448          2015        OH     99969      SERFF           6
# 11447          2015        OH     99969      SERFF           6
# 11446          2015        OH     99969      SERFF           6
# 11445          2015        OH     99969      SERFF           6
# 11443          2015        OH     99969      SERFF           6
#
#                ImportDate  IssuerId2         TIN  ProductId  \
# 11444 2015-01-21 12:15:34      99969  34-1442712        NaN
# 11439 2015-01-21 12:15:34      99969  34-1442712        NaN
# 20373 2015-08-27 03:52:03      99969  34-1442712        NaN
# ...

# %%
df_file.sort_values('BusinessYear').head(20)
# Out:
#       BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0             2014        AL     82285       HIOS           7
# 1410          2014        AR     60559      SERFF          10
# 1409          2014        AR     60559      SERFF          10
# 1408          2014        AR     60559      SERFF          10
# 1407          2014        AR     60559      SERFF          10
# 1406          2014        AR     60559      SERFF          10
# 1405          2014        AR     53741      SERFF           3
# 1404          2014        AR     48168      SERFF           1
# 1403          2014        AR     31227      SERFF           3
# 1402          2014        AR     31227      SERFF           3
# 1401          2014        AR     31227      SERFF           3
# 1400          2014        AR     31227      SERFF           3
# 1399          2014        AR     31227      SERFF           3
# 1398          2014        AR     31227      SERFF           3
# ...

# %%
Project_file_data = pd.read_csv(r'C:\Users\user\Desktop\newproject\Crosswalk2016.csv')

# %%
Project_file_data
# Out:
#        State DentalPlan     PlanID_2015  IssuerID_2015 MultistatePlan_2015  \
# 0         OR          N  10091OR0360004          10091                   N
# 1         OR          N  10091OR0360004          10091                   N
# 2         OR          N  10091OR0360004          10091                   N
# 3         OR          N  10091OR0360004          10091                   N
# 4         OR          N  10091OR0360004          10091                   N
# ...      ...        ...             ...            ...                 ...
# 150000    OH          Y  99969OH0060005          99969                   N
# 150001    OH          Y  99969OH0060005          99969                   N
# 150002    OH          Y  99969OH0060005          99969                   N
# 150003    OH          Y  99969OH0060005          99969                   N
# 150004    OH          Y  99969OH0060005          99969                   N
#
#        MetalLevel_2015  ChildAdultOnly_2015  FIPSCode  ZipCode  \
# ...

# %%
Project_file_data[Project_file_data.MetalLevel_2015 == "High"]
# Out:
#        State DentalPlan     PlanID_2015  IssuerID_2015 MultistatePlan_2015  \
# 432       OR          Y  10091OR0470002          10091                   N
# 433       OR          Y  10091OR0470002          10091                   N
# 434       OR          Y  10091OR0470002          10091                   N
# 435       OR          Y  10091OR0470002          10091                   N
# 436       OR          Y  10091OR0470002          10091                   N
# ...      ...        ...             ...            ...                 ...
# 150000    OH          Y  99969OH0060005          99969                   N
# 150001    OH          Y  99969OH0060005          99969                   N
# 150002    OH          Y  99969OH0060005          99969                   N
# 150003    OH          Y  99969OH0060005          99969                   N
# 150004    OH          Y  99969OH0060005          99969                   N
#
#        MetalLevel_2015  ChildAdultOnly_2015  FIPSCode  ZipCode  \
# ...

# %%
df_file['MetalLevel_2015'] = "High"

# %%
df_file
# Out:
#        BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0              2014        AL     82285       HIOS           7
# 1              2014        AL     82285       HIOS           7
# 2              2014        AL     82285       HIOS           7
# 3              2014        AL     82285       HIOS           7
# 4              2014        AL     82285       HIOS           7
# ...             ...       ...       ...        ...         ...
# 21080          2016        WV     94562      SERFF           2
# 21081          2016        WV     96480      SERFF           2
# 21082          2016        WV     96480      SERFF           2
# 21083          2016        WV     96480      SERFF           2
# 21084          2016        WV     96480      SERFF           2
#
#                ImportDate  IssuerId2         TIN  ProductId  \
# 0     2014-01-21 08:29:49      82285  94-2761537        NaN
# 1     2014-01-21 08:29:49      82285  94-2761537        NaN
# ...

# %%
df_file_div = df_file[['IssuerId','IssuerId2']].std()
df_file_div
# Out:
# IssuerId     26097.535028
# IssuerId2    26097.535028
# dtype: float64

# %%
variance_file = df_file[['IssuerId','IssuerId2']].var()
variance_file
# Out:
# IssuerId     6.810813e+08
# IssuerId2    6.810813e+08
# dtype: float64

# %%
correlation_data = df[['IssuerId','IssuerId2']].corr()
correlation_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[188], line 1
# ----> 1 correlation_data = df[['IssuerId','IssuerId2']].corr()
#       2 correlation_data
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df_file.hist(figsize=(18,8));
plt.tight_layout();

# %%
df_file.head(2)
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2014        AL     82285       HIOS           7
# 1          2014        AL     82285       HIOS           7
#
#            ImportDate  IssuerId2         TIN  ProductId StandardComponentId  \
# 0 2014-01-21 08:29:49      82285  94-2761537        NaN      82285AL0010006
# 1 2014-01-21 08:29:49      82285  94-2761537        NaN      82285AL0020001
#
#    ... MinimumTobaccoFreeMonthsRule  \
# 0  ...               Not Applicable
# 1  ...               Not Applicable
#
#                                     CohabitationRule RowNumber MarketCoverage  \
# 0  Spouse,No;Adopted Child,No;Foster Child,No;War...        14     Individual
# 1  Adopted Child,Yes;Foster Child,Yes;Stepson or ...        15     Individual
#
#   DentalOnlyPlan  year month weekday day MetalLevel_2015
# 0            Yes  2014     1       1  21            High
# 1            Yes  2014     1       1  21            High
#
# [2 rows x 28 columns]

# %%
IssuerId.hist(figsize(18,8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[212], line 1
# ----> 1 IssuerId.hist(figsize(18,8))
#
# NameError: name 'IssuerId' is not defined
